# %% [markdown]
# # Stratospheric Ozone - A Good News Environment Story!
#
# Let's familiarize ourselves with Python by taking a look at an example using data from [Our World in Data](https://ourworldindata.org/ozone-layer)
#
# Read over the introduction to this webpage and then scroll down to the "Interactive Charts on the Ozone Layer" section. Click on the "Concentration of Ozone in the Stratosphere" panel on the left-hand side and download the full csv file.
#
# We're going to need two python packages: `numpy` and `matplotlib`

# %%
#  import numpy and matplotlib
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Now, let's read in our csv file:

# %%
#  read in ozone data
o3 = np.genfromtxt('stratospheric-ozone-concentration.csv',delimiter=',')

# %% [markdown]
# Let's look at the data. The first thing I typically do is check the shape of the data:

# %%
#  check the shape of your data

# %% [markdown]
# How do you interpret this shape?
#
# Now, that we understand what our data structure is, let's plot the mean daily concentration as a function of year.

# %%
#  plot your ozone concentration data

# %% [markdown]
# What does the shape of the time series suggest about what's going on?
#
# Now, let's take the time mean of our data. What mean would be most meaningful?

# %%
#  compute the time mean

# %% [markdown]
# Finally, let's consider the variability of our data but computing the standard deviation. Again, what standard deviation would be most meaningful?
